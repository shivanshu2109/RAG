# %% [markdown]
# ## Data Ingestion ##

# %% [markdown]
# ### Document Strucuture

# %%
from langchain_core.documents import Document

# %%
doc = Document(
    page_content = " This is the main text content I am using to create RAG",
    metadata = {
        "source" : "example.txt",
        "pages" : 1,
        "author" : "Shivanshu Mishra",
        "date_created" : "2025-01-01"
    }
)
doc
# Out:
# Document(metadata={'source': 'example.txt', 'pages': 1, 'author': 'Shivanshu Mishra', 'date_created': '2025-01-01'}, page_content=' This is the main text content I am using to create RAG')

# %%
## Create a simple txt file
import os
os.makedirs("../data/text_files",exist_ok = True)

# %%
sample_texts={
    "../data/text_files/python_intro.txt":"""Python Programming Introduction

Python is a high-level, interpreted programming language known for its simplicity and readability.
Created by Guido van Rossum and first released in 1991, Python has become one of the most popular
programming languages in the world.

Key Features:
- Easy to learn and use
- Extensive standard library
- Cross-platform compatibility
- Strong community support

Python is widely used in web development, data science, artificial intelligence, and automation.""",
    
    "../data/text_files/machine_learning.txt": """Machine Learning Basics

Machine learning is a subset of artificial intelligence that enables systems to learn and improve
from experience without being explicitly programmed. It focuses on developing computer programs
that can access data and use it to learn for themselves.

Types of Machine Learning:
1. Supervised Learning: Learning with labeled data
2. Unsupervised Learning: Finding patterns in unlabeled data
3. Reinforcement Learning: Learning through rewards and penalties

Applications include image recognition, speech processing, and recommendation systems
    
    
    """

}

for filepath,content in sample_texts.items():
    with open(filepath,'w',encoding="utf-8") as f:
        f.write(content)

print("✅ Sample text files created!")
# Out:
# ✅ Sample text files created!

# %% [markdown]
# ### Text Loader

# %%
from langchain_community.document_loaders import TextLoader

loader = TextLoader("../data/text_files/python_intro.txt",encoding = 'utf-8')
document = loader.load()
print(document)
# Out:
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content='Python Programming Introduction\n\nPython is a high-level, interpreted programming language known for its simplicity and readability.\nCreated by Guido van Rossum and first released in 1991, Python has become one of the most popular\nprogramming languages in the world.\n\nKey Features:\n- Easy to learn and use\n- Extensive standard library\n- Cross-platform compatibility\n- Strong community support\n\nPython is widely used in web development, data science, artificial intelligence, and automation.')]

# %% [markdown]
# ### Directory Loader

# %%
from langchain_community.document_loaders import DirectoryLoader

# Load all the text files from the directory
dir_loader = DirectoryLoader(
    "../data/text_files",
    glob = "**/*.txt", # pattern to match files
    loader_cls = TextLoader, # Lodaer class to use
    loader_kwargs = {'encoding' : 'utf-8'},
    show_progress = False
)

documents = dir_loader.load()
print(documents)
# Out:
# [Document(metadata={'source': '..\\data\\text_files\\machine_learning.txt'}, page_content='Machine Learning Basics\n\nMachine learning is a subset of artificial intelligence that enables systems to learn and improve\nfrom experience without being explicitly programmed. It focuses on developing computer programs\nthat can access data and use it to learn for themselves.\n\nTypes of Machine Learning:\n1. Supervised Learning: Learning with labeled data\n2. Unsupervised Learning: Finding patterns in unlabeled data\n3. Reinforcement Learning: Learning through rewards and penalties\n\nApplications include image recognition, speech processing, and recommendation systems\n    \n    \n    '), Document(metadata={'source': '..\\data\\text_files\\python_intro.txt'}, page_content='Python Programming Introduction\n\nPython is a high-level, interpreted programming language known for its simplicity and readability.\nCreated by Guido van Rossum and first released in 1991, Python has become one of the most popular\nprogramming languages in the world.\n\nKey Features:\n- Easy to learn and use\n- Extensive standard library\n- Cross-platform compatibility\n- Strong community support\n\nPython is widely used in web development, data science, artificial intelligence, and automation.')]

# %%
from langchain_community.document_loaders import PyPDFLoader, PyMuPDFLoader

# Load all the text files from the directory
dir_loader = DirectoryLoader(
    "../data/pdf",
    glob = "**/*.pdf", # pattern to match files
    loader_cls = PyMuPDFLoader, # Lodaer class to use
    # loader_kwargs = {'encoding' : 'utf-8'},
    show_progress = False
)

pdf_documents = dir_loader.load()
print(pdf_documents)
# Out:
# [Document(metadata={'producer': 'Microsoft® Word for Microsoft 365', 'creator': 'Microsoft® Word for Microsoft 365', 'creationdate': '2026-04-14T23:31:23-04:00', 'source': '..\\data\\pdf\\Shivanshu-Mishra-Resume .pdf', 'file_path': '..\\data\\pdf\\Shivanshu-Mishra-Resume .pdf', 'total_pages': 2, 'format': 'PDF 1.7', 'title': '', 'author': 'Shivanshu Mishra', 'subject': '', 'keywords': '', 'moddate': '2026-04-14T23:31:23-04:00', 'trapped': '', 'modDate': "D:20260414233123-04'00'", 'creationDate': "D:20260414233123-04'00'", 'page': 0}, page_content='SHIVANSHU MISHRA \n New York ∙ Ph: 716-612-0226 ∙ shivanshu985@gmail.com ∙ LinkedIn ∙ GitHub ∙ Portfolio \nEDUCATION\n \nM.S in Artificial Intelligence | SUNY Buffalo, NY \n     Aug 2024 – Dec 2025 \nB.E in AI & ML | University of Mumbai, India \n      Jun 2020 – Jul 2024 \nSUMMARY \nI am driven AI and Software Engineer with a deep curiosity for exploring emerging technologies and rapidly adapting \nto new challenges. I am a highly collaborative team player who thrives on sharing ideas and working alongside others \nto turn concepts into reality. My true passion lies in the creative process of building new, user-focused tools and \napplications from the ground up. Ultimately, I am dedicated to continuous learning and making impactful solutions that \nbridge the gap between innovative engineering and everyday use. \nWORK EXPERIENCE \nAI Engineer Intern – Samtek – Virginia \n    June 2025 – August 2025 \n• \nUsed Python, AWS Bedrock, and NLP to develop a robust scalable, AI-powered cloud configuration system that \nautomatically converts cloud setup files, reducing manual effort by 30 hours per week. \n• \nDesigned a Stream-lit based app using Fast API and CI/CD pipeline for file handling, conversion and validation \nusing LLMs across different cloud platforms and using Power BI dashboards for real-time process monitoring. \n• \nCreated a dual-interface platform accessible to technical and non-technical users alike, integrating web and CLI \naccess to simplify workflows and boost cross-team adoption. \n• \nImplemented a caching framework using Python OOP and Machine Learning libraries (NumPy, Pandas, scikit- \nlearn), cutting API calls by 80% and enabling faster cache tracking. \nSoftware Engineer Intern – Alternative Clinic – Mumbai, India \n             June 2023 – June 2024 \n• \nArchitected an end-to-end Document AI pipeline integrating AWS Textract and an LLM API (OpenAI) to transform \nunstructured PDF invoices into structured, queryable ESG carbon metrics. \n• \nBuilt a Python-based vector search engine using FAISS and OpenAI sentence embeddings to map extracted \nmaterials to a custom PostgreSQL database, replacing brittle rule-based lookups with NLP semantic matching. \n• \nGenerated a synthetic dataset of 200+ noise-augmented PDF documents using Faker and ReportLab to validate \nthe resilience of the extraction pipeline against real-world document variations. \n• \nDesigned data architecture and cloud infrastructure, automating ingestion into PostgreSQL via SQLAlchemy and \nprovisioning secure AWS services (S3, Textract, IAM). \nAI and ML Intern – Alternative Clinic – Mumbai, India \n      January 2023 – April 2023 \n• \nArchitected an AI-powered Clinical Decision Support System using Python (Fast API) and AWS (RDS, S3, EC2), \ncombining PostgreSQL for structured patient records with Chroma DB for semantic search across clinical notes. \n• \nBuilt a RAG (Retrieval-Augmented Generation) pipeline using Lang Chain to enable natural language Q&A over \npatient histories, converting doctor queries into vector embeddings. \n• \nDeveloped a multi-stage data ingestion pipeline using AWS Textract and PyPDF2 to preprocess unstructured \nclinical reports, implementing recursive character splitting to optimize chunk sizes for high-fidelity vector storage. \n• \nEngineered an interactive physician dashboard using Streamlit, enabling real-time Patient ID lookups, automated \nclinical summa ...

# %%
type(pdf_documents[0])
# Out:
# langchain_core.documents.base.Document
